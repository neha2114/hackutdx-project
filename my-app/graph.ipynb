# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load data from a CSV file into a Pandas DataFrame:
df = pd.read_csv("HackUTD-2023-HomeBuyerInfo.csv")

sns.scatterplot(data = df, x = "LoanAmount", y = "AppraisedValue")

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load data from a CSV file into a Pandas DataFrame:
df = pd.read_csv("HackUTD-2023-HomeBuyerInfo.csv")

sns.scatterplot(data = df, x = "LoanAmount", y = "MonthlyMortgagePayment")

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load data from a CSV file into a Pandas DataFrame:
df = pd.read_csv("HackUTD-2023-HomeBuyerInfo.csv")

sns.scatterplot(data = df, x = "CreditScore", y = "MonthlyMortgagePayment")

plt.show()
